# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from mpl_toolkits.mplot3d import axes3d

# %%
style.use('ggplot')
data = pd.read_excel(r'C:\Users\luong\Downloads\Demo_Datachart.xlsx', sheet_name="Sheet2")

# %%
x = list(data['X'])
y = list(data["Y"])
z = list(data["Z"])
# x = list(x)
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.plot(x, y, z)
# ax1.scatter(x2, y2, z2, c ='r', marker='o')

ax1.set_xlabel('x axis')
ax1.set_ylabel('y axis')
ax1.set_zlabel('z axis')

plt.show()
